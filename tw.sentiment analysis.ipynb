# %%
# !pip install tweepy

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/624.3 kB ? eta -:--:--
#    ---------------------------------------- 624.3/624.3 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import tweepy 
from textblob import TextBlob
import matplotlib.pyplot as plt

# %% [markdown]
# Tweepy: This library is used to access the Twitter API, which allows us to fetch tweets directly from Twitter.
#
# TextBlob: A simple library for processing textual data. It provides a simple API for diving into common natural language processing (NLP) tasks, such as part-of-speech tagging, noun phrase extraction, sentiment analysis, classification, translation, and more.
#
# Pandas: A powerful data manipulation tool that allows us to handle and analyze data in a flexible way. It provides data structures and functions needed to manipulate and analyze structured data seamlessly.
#
# Matplotlib: A plotting library for creating static, animated, and interactive visualizations in Python. It's widely used for plotting graphs and visualizing data in a comprehensible manner.
#
# Step 3: Twitter API Credentials
# In the next cell, set up your Twitter API credentials:

# %%
'''consumer_key='cgf7fXiM1VNYiXb2cUDR6CsEc'
consumer_secret_key='BMWQ8FiniOfTnx2QtZMP51Tyml0gsa0EOgHa2sgWqkmSdIgSer'
access_token='1508656416113917954-ciBd5C9iIBe3JEDXHoX7HHRbyNsIUC'
access_token_key='LppPk3pDmoJyYW7k14WnjFgJGfklznHXA6DeupbWDLkdB'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAAZiygEAAAAAaL2BxPXSm1bMez6ODxl7gQLx9NE%3D3RI9bdibSDrLm2Dj6b2w4s9u4OyQQupfYhDNTYPLfH9h3yQvGG'

auth = tweepy.OAuthHandler(consumer_key,consumer_secret_key)
auth.set_access_token(access_token,access_token_key)
api = tweepy.API(auth)'''
import pandas as pd
import tweepy
from textblob import TextBlob
import matplotlib.pyplot as plt

# Your Twitter API credentials
consumer_key = 'cgf7fXiM1VNYiXb2cUDR6CsEc'
consumer_secret_key = 'BMWQ8FiniOfTnx2QtZMP51Tyml0gsa0EOgHa2sgWqkmSdIgSer'
access_token = '1508656416113917954-ciBd5C9iIBe3JEDXHoX7HHRbyNsIUC'
access_token_key = 'LppPk3pDmoJyYW7k14WnjFgJGfklznHXA6DeupbWDLkdB'
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAAZiygEAAAAAaL2BxPXSm1bMez6ODxl7gQLx9NE%3D3RI9bdibSDrLm2Dj6b2w4s9u4OyQQupfYhDNTYPLfH9h3yQvGG'

# Authenticate to Twitter
client = tweepy.Client(bearer_token=bearer_token)

# Search for recent tweets
query = 'python'
tweets = client.search_recent_tweets(query=query, max_results=100)

# Process the tweets
for tweet in tweets.data:
    print(tweet.text)
# Out:
# RT @jino_rohit: The more I work with amazing people who write amazing code, the more I feel I should improve my overall code quality. Divin…
# RT @defholicsin: GOT7???     ʸᵉˢ
#
# ㅡ @GOT7Official @GOT7 #GOT7 #갓세븐
# #GOT7_WINTER_HEPTAGON #GOT7_PYTHON https://t.co/06Sgt8vCLg
# @pythoncoruna Su experiencia y compromiso enriquecen nuestra programación, añadiendo una perspectiva valiosa para todos los asistentes interesados en la tecnología y la innovación.
#
# ¿Listo para un hackeo mental? Únete a Python Coruña y Lareira Conf!
# @pythoncoruna En la #LareiraConf25 , nos enorgullece contar con Python Coruña como colaborador clave en la creación de nuestro evento.
# @pythoncoruna Con una programación activa de reuniones y talleres, Python Coruña fomenta el intercambio de conocimientos en áreas como desarrollo web, ciencia de datos y aprendizaje automático.
# RT @BBowyo: 🎉🎉Python 10 M 🎉🎉
# เพลงมาแรง#1 ตลอด 9 วัน 9 คืน
# ปังมากกกก 🥹🥹
# 💚💚💚💚💚💚💚
#
# 💰แจก 100 THB💰 (สุ่ม 31)
# ...

# %% [markdown]
# Why This Step?
# To access Twitter's data, we need to authenticate ourselves via the Twitter API. By providing these credentials, we gain access to Twitter's streaming and REST APIs, which allow us to fetch tweets and other related data.
#
# Step 4: Fetch Tweets and Perform Sentiment Analysis
# Create a function to fetch tweets and perform sentiment analysis. Add the following cell:

# %%
import tweepy
from textblob import TextBlob
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Replace with your own Bearer Token
bearer_token = 'AAAAAAAAAAAAAAAAAAAAAAZiygEAAAAAaL2BxPXSm1bMez6ODxl7gQLx9NE%3D3RI9bdibSDrLm2Dj6b2w4s9u4OyQQupfYhDNTYPLfH9h3yQvGG'

# Authenticate to Twitter
client = tweepy.Client(bearer_token=bearer_token)

# Define the search query and the maximum number of tweets to retrieve
query = 'python'
tweets = client.search_recent_tweets(query=query, max_results=100)

# Process the tweets and perform sentiment analysis
tweet_list = [[tweet.text, TextBlob(tweet.text).sentiment.polarity] for tweet in tweets.data]
df = pd.DataFrame(tweet_list, columns=['Tweet', 'Sentiment'])
# Analyze and visualize the results
df['Sentiment_Label'] = df['Sentiment'].apply(lambda x: 'Positive' if x > 0 else ('Negative' if x < 0 else 'Neutral'))
sentiment_counts = df['Sentiment_Label'].value_counts()

# Plotting the sentiment counts
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['green', 'red', 'blue'])
plt.title('Sentiment Analysis of Tweets')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# Cell In[38], line 9
#       7 # Define the search query and the maximum number of tweets to retrieve
#       8 query = 'python'
# ----> 9 tweets = client.search_recent_tweets(query=query, max_results=100)
#      11 # Process the tweets and perform sentiment analysis
#      12 tweet_list = [[tweet.text, TextBlob(tweet.text).sentiment.polarity] for tweet in tweets.data]
#
# File ~\anaconda3\Lib\site-packages\tweepy\client.py:1270, in Client.search_recent_tweets(self, query, user_auth, **params)
#    1178 """search_recent_tweets( \
#    1179     query, *, end_time=None, expansions=None, max_results=None, \
#    1180     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1267 .. _Academic Research Project: https://developer.twitter.com/en/docs/projects
#    1268 """
#    1269 params["query"] = query
# ...
